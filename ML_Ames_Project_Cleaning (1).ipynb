# %% [markdown]
# # Project Workflow:
#
# The data:
# The Ames housing dataset consists of about  2500  house sale records between  2006−2010 . Detailed information about the house attributes, along with the sale prices, is recorded in the dataset.
#
# Goal:perform descriptive data analysis to gain business (i.e. housing market) insights
# build descriptive machine learning models to understand the local housing market.
# build predictive machine learning models for the local house price prediction.
#
# Approach:You are a housing market consultant.
# You are a data scientist for an online real estate database company which provides house price estimation (like Zillow home price estimates) for the site visitors.
#
# Tools you are expected to use:
# Data analysis and missing value imputation: pandas, dplr, and the accompanying visualization tools, some multiple linear regression or logistic regression.
# Descriptive models: feature selection, feature engineering, multiple linear regression, Python statsmodels or their R couterpart, penalized linear regression, stepwise regression (AIC, BIC, etc.), some gridsearch, KNN, SVR, Random Forest, Gradient Boosting, and potentially other models.
# Predictive models: feature selection, feature engineering, gridsearchCV, multiple/penalized linear regression, gridsearch, Random Forest, Gradient Boosting, and potentially other models.

# %% [markdown]
# # column info from kaggle:
# PID: Parcel ID
# MSSubClass: Identifies the type of dwelling involved in the sale.
#
#         20	1-STORY 1946 & NEWER ALL STYLES
#         30	1-STORY 1945 & OLDER
#         40	1-STORY W/FINISHED ATTIC ALL AGES
#         45	1-1/2 STORY - UNFINISHED ALL AGES
#         50	1-1/2 STORY FINISHED ALL AGES
#         60	2-STORY 1946 & NEWER
#         70	2-STORY 1945 & OLDER
#         75	2-1/2 STORY ALL AGES
#         80	SPLIT OR MULTI-LEVEL
#         85	SPLIT FOYER
#         90	DUPLEX - ALL STYLES AND AGES
#        120	1-STORY PUD (Planned Unit Development) - 1946 & NEWER
#        150	1-1/2 STORY PUD - ALL AGES
#        160	2-STORY PUD - 1946 & NEWER
#        180	PUD - MULTILEVEL - INCL SPLIT LEV/FOYER
#        190	2 FAMILY CONVERSION - ALL STYLES AND AGES
#
# MSZoning: Identifies the general zoning classification of the sale.
#
#        A	Agriculture
#        C	Commercial
#        FV	Floating Village Residential
#        I	Industrial
#        RH	Residential High Density
#        RL	Residential Low Density
#        RP	Residential Low Density Park
#        RM	Residential Medium Density
#
# LotFrontage: Linear feet of street connected to property
#
# LotArea: Lot size in square feet
#
# Street: Type of road access to property
#
#        Grvl	Gravel
#        Pave	Paved
#
# Alley: Type of alley access to property
#
#        Grvl	Gravel
#        Pave	Paved
#        NA 	No alley access
#
# LotShape: General shape of property
#
#        Reg	Regular
#        IR1	Slightly irregular
#        IR2	Moderately Irregular
#        IR3	Irregular
#
# LandContour: Flatness of the property
#
#        Lvl	Near Flat/Level
#        Bnk	Banked - Quick and significant rise from street grade to building
#        HLS	Hillside - Significant slope from side to side
#        Low	Depression
#
# Utilities: Type of utilities available
#
#        AllPub	All public Utilities (E,G,W,& S)
#        NoSewr	Electricity, Gas, and Water (Septic Tank)
#        NoSeWa	Electricity and Gas Only
#        ELO	Electricity only
#
# LotConfig: Lot configuration
#
#        Inside	Inside lot
#        Corner	Corner lot
#        CulDSac	Cul-de-sac
#        FR2	Frontage on 2 sides of property
#        FR3	Frontage on 3 sides of property
#
# LandSlope: Slope of property
#
#        Gtl	Gentle slope
#        Mod	Moderate Slope
#        Sev	Severe Slope
#
# Neighborhood: Physical locations within Ames city limits
#
#        Blmngtn	Bloomington Heights
#        Blueste	Bluestem
#        BrDale	Briardale
#        BrkSide	Brookside
#        ClearCr	Clear Creek
#        CollgCr	College Creek
#        Crawfor	Crawford
#        Edwards	Edwards
#        Gilbert	Gilbert
#        IDOTRR	Iowa DOT and Rail Road
#        MeadowV	Meadow Village
#        Mitchel	Mitchell
#        Names	North Ames
#        NoRidge	Northridge
#        NPkVill	Northpark Villa
#        NridgHt	Northridge Heights
#        NWAmes	Northwest Ames
#        OldTown	Old Town
#        SWISU	South & West of Iowa State University
#        Sawyer	Sawyer
#        SawyerW	Sawyer West
#        Somerst	Somerset
#        StoneBr	Stone Brook
#        Timber	Timberland
#        Veenker	Veenker
#
# Condition1: Proximity to various conditions
#
#        Artery	Adjacent to arterial street
#        Feedr	Adjacent to feeder street
#        Norm	Normal
#        RRNn	Within 200' of North-South Railroad
#        RRAn	Adjacent to North-South Railroad
#        PosN	Near positive off-site feature--park, greenbelt, etc.
#        PosA	Adjacent to postive off-site feature
#        RRNe	Within 200' of East-West Railroad
#        RRAe	Adjacent to East-West Railroad
#
# Condition2: Proximity to various conditions (if more than one is present)
#
#        Artery	Adjacent to arterial street
#        Feedr	Adjacent to feeder street
#        Norm	Normal
#        RRNn	Within 200' of North-South Railroad
#        RRAn	Adjacent to North-South Railroad
#        PosN	Near positive off-site feature--park, greenbelt, etc.
#        PosA	Adjacent to postive off-site feature
#        RRNe	Within 200' of East-West Railroad
#        RRAe	Adjacent to East-West Railroad
#
# BldgType: Type of dwelling
#
#        1Fam	Single-family Detached
#        2FmCon	Two-family Conversion; originally built as one-family dwelling
#        Duplx	Duplex
#        TwnhsE	Townhouse End Unit
#        TwnhsI	Townhouse Inside Unit
#
# HouseStyle: Style of dwelling
#
#        1Story	One story
#        1.5Fin	One and one-half story: 2nd level finished
#        1.5Unf	One and one-half story: 2nd level unfinished
#        2Story	Two story
#        2.5Fin	Two and one-half story: 2nd level finished
#        2.5Unf	Two and one-half story: 2nd level unfinished
#        SFoyer	Split Foyer
#        SLvl	Split Level
#
# OverallQual: Rates the overall material and finish of the house
#
#        10	Very Excellent
#        9	Excellent
#        8	Very Good
#        7	Good
#        6	Above Average
#        5	Average
#        4	Below Average
#        3	Fair
#        2	Poor
#        1	Very Poor
#
# OverallCond: Rates the overall condition of the house
#
#        10	Very Excellent
#        9	Excellent
#        8	Very Good
#        7	Good
#        6	Above Average
#        5	Average
#        4	Below Average
#        3	Fair
#        2	Poor
#        1	Very Poor
#
# YearBuilt: Original construction date
#
# YearRemodAdd: Remodel date (same as construction date if no remodeling or additions)
#
# RoofStyle: Type of roof
#
#        Flat	Flat
#        Gable	Gable
#        Gambrel	Gabrel (Barn)
#        Hip	Hip
#        Mansard	Mansard
#        Shed	Shed
#
# RoofMatl: Roof material
#
#        ClyTile	Clay or Tile
#        CompShg	Standard (Composite) Shingle
#        Membran	Membrane
#        Metal	Metal
#        Roll	Roll
#        Tar&Grv	Gravel & Tar
#        WdShake	Wood Shakes
#        WdShngl	Wood Shingles
#
# Exterior1st: Exterior covering on house
#
#        AsbShng	Asbestos Shingles
#        AsphShn	Asphalt Shingles
#        BrkComm	Brick Common
#        BrkFace	Brick Face
#        CBlock	Cinder Block
#        CemntBd	Cement Board
#        HdBoard	Hard Board
#        ImStucc	Imitation Stucco
#        MetalSd	Metal Siding
#        Other	Other
#        Plywood	Plywood
#        PreCast	PreCast
#        Stone	Stone
#        Stucco	Stucco
#        VinylSd	Vinyl Siding
#        Wd Sdng	Wood Siding
#        WdShing	Wood Shingles
#
# Exterior2nd: Exterior covering on house (if more than one material)
#
#        AsbShng	Asbestos Shingles
#        AsphShn	Asphalt Shingles
#        BrkComm	Brick Common
#        BrkFace	Brick Face
#        CBlock	Cinder Block
#        CemntBd	Cement Board
#        HdBoard	Hard Board
#        ImStucc	Imitation Stucco
#        MetalSd	Metal Siding
#        Other	Other
#        Plywood	Plywood
#        PreCast	PreCast
#        Stone	Stone
#        Stucco	Stucco
#        VinylSd	Vinyl Siding
#        Wd Sdng	Wood Siding
#        WdShing	Wood Shingles
#
# MasVnrType: Masonry veneer type
#
#        BrkCmn	Brick Common
#        BrkFace	Brick Face
#        CBlock	Cinder Block
#        None	None
#        Stone	Stone
#
# MasVnrArea: Masonry veneer area in square feet
#
# ExterQual: Evaluates the quality of the material on the exterior
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor
#
# ExterCond: Evaluates the present condition of the material on the exterior
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor
#
# Foundation: Type of foundation
#
#        BrkTil	Brick & Tile
#        CBlock	Cinder Block
#        PConc	Poured Contrete
#        Slab	Slab
#        Stone	Stone
#        Wood	Wood
#
# BsmtQual: Evaluates the height of the basement
#
#        Ex	Excellent (100+ inches)
#        Gd	Good (90-99 inches)
#        TA	Typical (80-89 inches)
#        Fa	Fair (70-79 inches)
#        Po	Poor (<70 inches
#        NA	No Basement
#
# BsmtCond: Evaluates the general condition of the basement
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical - slight dampness allowed
#        Fa	Fair - dampness or some cracking or settling
#        Po	Poor - Severe cracking, settling, or wetness
#        NA	No Basement
#
# BsmtExposure: Refers to walkout or garden level walls
#
#        Gd	Good Exposure
#        Av	Average Exposure (split levels or foyers typically score average or above)
#        Mn	Mimimum Exposure
#        No	No Exposure
#        NA	No Basement
#
# BsmtFinType1: Rating of basement finished area
#
#        GLQ	Good Living Quarters
#        ALQ	Average Living Quarters
#        BLQ	Below Average Living Quarters
#        Rec	Average Rec Room
#        LwQ	Low Quality
#        Unf	Unfinshed
#        NA	No Basement
#
# BsmtFinSF1: Type 1 finished square feet
#
# BsmtFinType2: Rating of basement finished area (if multiple types)
#
#        GLQ	Good Living Quarters
#        ALQ	Average Living Quarters
#        BLQ	Below Average Living Quarters
#        Rec	Average Rec Room
#        LwQ	Low Quality
#        Unf	Unfinshed
#        NA	No Basement
#
# BsmtFinSF2: Type 2 finished square feet
#
# BsmtUnfSF: Unfinished square feet of basement area
#
# TotalBsmtSF: Total square feet of basement area
#
# Heating: Type of heating
#
#        Floor	Floor Furnace
#        GasA	Gas forced warm air furnace
#        GasW	Gas hot water or steam heat
#        Grav	Gravity furnace
#        OthW	Hot water or steam heat other than gas
#        Wall	Wall furnace
#
# HeatingQC: Heating quality and condition
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor
#
# CentralAir: Central air conditioning
#
#        N	No
#        Y	Yes
#
# Electrical: Electrical system
#
#        SBrkr	Standard Circuit Breakers & Romex
#        FuseA	Fuse Box over 60 AMP and all Romex wiring (Average)
#        FuseF	60 AMP Fuse Box and mostly Romex wiring (Fair)
#        FuseP	60 AMP Fuse Box and mostly knob & tube wiring (poor)
#        Mix	Mixed
#
# 1stFlrSF: First Floor square feet
#
# 2ndFlrSF: Second floor square feet
#
# LowQualFinSF: Low quality finished square feet (all floors)
#
# GrLivArea: Above grade (ground) living area square feet
#
# BsmtFullBath: Basement full bathrooms
#
# BsmtHalfBath: Basement half bathrooms
#
# FullBath: Full bathrooms above grade
#
# HalfBath: Half baths above grade
#
# Bedroom: Bedrooms above grade (does NOT include basement bedrooms)
#
# Kitchen: Kitchens above grade
#
# KitchenQual: Kitchen quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor
#
# TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)
#
# Functional: Home functionality (Assume typical unless deductions are warranted)
#
#        Typ	Typical Functionality
#        Min1	Minor Deductions 1
#        Min2	Minor Deductions 2
#        Mod	Moderate Deductions
#        Maj1	Major Deductions 1
#        Maj2	Major Deductions 2
#        Sev	Severely Damaged
#        Sal	Salvage only
#
# Fireplaces: Number of fireplaces
#
# FireplaceQu: Fireplace quality
#
#        Ex	Excellent - Exceptional Masonry Fireplace
#        Gd	Good - Masonry Fireplace in main level
#        TA	Average - Prefabricated Fireplace in main living area or Masonry Fireplace in basement
#        Fa	Fair - Prefabricated Fireplace in basement
#        Po	Poor - Ben Franklin Stove
#        NA	No Fireplace
#
# GarageType: Garage location
#
#        2Types	More than one type of garage
#        Attchd	Attached to home
#        Basment	Basement Garage
#        BuiltIn	Built-In (Garage part of house - typically has room above garage)
#        CarPort	Car Port
#        Detchd	Detached from home
#        NA	No Garage
#
# GarageYrBlt: Year garage was built
#
# GarageFinish: Interior finish of the garage
#
#        Fin	Finished
#        RFn	Rough Finished
#        Unf	Unfinished
#        NA	No Garage
#
# GarageCars: Size of garage in car capacity
#
# GarageArea: Size of garage in square feet
#
# GarageQual: Garage quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor
#        NA	No Garage
#
# GarageCond: Garage condition
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor
#        NA	No Garage
#
# PavedDrive: Paved driveway
#
#        Y	Paved
#        P	Partial Pavement
#        N	Dirt/Gravel
#
# WoodDeckSF: Wood deck area in square feet
#
# OpenPorchSF: Open porch area in square feet
#
# EnclosedPorch: Enclosed porch area in square feet
#
# 3SsnPorch: Three season porch area in square feet
#
# ScreenPorch: Screen porch area in square feet
#
# PoolArea: Pool area in square feet
#
# PoolQC: Pool quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        NA	No Pool
#
# Fence: Fence quality
#
#        GdPrv	Good Privacy
#        MnPrv	Minimum Privacy
#        GdWo	Good Wood
#        MnWw	Minimum Wood/Wire
#        NA	No Fence
#
# MiscFeature: Miscellaneous feature not covered in other categories
#
#        Elev	Elevator
#        Gar2	2nd Garage (if not described in garage section)
#        Othr	Other
#        Shed	Shed (over 100 SF)
#        TenC	Tennis Court
#        NA	None
#
# MiscVal: $Value of miscellaneous feature
#
# MoSold: Month Sold (MM)
#
# YrSold: Year Sold (YYYY)
#
# SaleType: Type of sale
#
#        WD 	Warranty Deed - Conventional
#        CWD	Warranty Deed - Cash
#        VWD	Warranty Deed - VA Loan
#        New	Home just constructed and sold
#        COD	Court Officer Deed/Estate
#        Con	Contract 15% Down payment regular terms
#        ConLw	Contract Low Down payment and low interest
#        ConLI	Contract Low Interest
#        ConLD	Contract Low Down
#        Oth	Other
#
# SaleCondition: Condition of sale
#
#        Normal	Normal Sale
#        Abnorml	Abnormal Sale -  trade, foreclosure, short sale
#        AdjLand	Adjoining Land Purchase
#        Alloca	Allocation - two linked properties with separate deeds, typically condo with a garage unit
#        Family	Sale between family members
#        Partial	Home was not completed when last assessed (associated with New Homes)

# %%
#importing necessary modules
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline
from sklearn.feature_selection import f_regression
from sklearn.linear_model import LinearRegression
plt.style.use("ggplot")

# %%
#reading in the ames housing data
housing = pd.read_csv("Ames_HousePrice.csv", index_col=0)
copy = housing
print("Ames Housing Data Shape:", housing.shape)
# Out:
# Ames Housing Data Shape: (2580, 81)

# %%
#reading in the ames accessor data
real_estate = pd.read_csv("Ames Real Estate Data.csv", index_col=0)
real_estate.shape
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (36,40,81,87) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# (22213, 90)

# %%
#I will use the georef column to match with the PID and merge the dfs 
address = real_estate.filter(regex="GeoRefNo$|Prop_Addr$")

address.head()
# Out:
#             GeoRefNo                 Prop_Addr
# MapRefNo
# 520400001  520400001  4599 GEORGE W CARVER AVE
# 520440010  520440010         4507 EVEREST  AVE
# 520440020  520440020         4513 EVEREST  AVE
# 520445001  520445001          3449 BARCELOS ST
# 520445010  520445010         4506 EVEREST  AVE

# %%
# Rename the rest of the columns for easier accessing
address = address.rename(columns={"GeoRefNo":"PID"})


#by merging the dataframes we will be able to get the lat/long coords from address
ames_merge = pd.merge(
    housing,
    address,
    how="inner",
    on="PID",
    left_index=False,
    right_index=False,
    sort=False,
    suffixes=("_x", "_y"),
    copy=True,
    indicator=False,
    validate=None,
)

ames_merge.shape
# Out:
# (2604, 82)

# %% [markdown]
# looks like we may have some duplicates...

# %%
#checking columns and data types:
print("Columns: ", ames_merge.columns)

print("Ames Summary: ", ames_merge.info())

print("Total Unique Values: ", ames_merge.nunique())
# Out:
# Columns:  Index(['PID', 'GrLivArea', 'SalePrice', 'MSSubClass', 'MSZoning',
#        'LotFrontage', 'LotArea', 'Street', 'Alley', 'LotShape', 'LandContour',
#        'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1',
#        'Condition2', 'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond',
#        'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF',
#        '2ndFlrSF', 'LowQualFinSF', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'Prop_Addr'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2604 entries, 0 to 2603
# Data columns (total 82 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PID            2604 non-null   int64
#  1   GrLivArea      2604 non-null   int64
#  2   SalePrice      2604 non-null   int64
#  3   MSSubClass     2604 non-null   int64
#  4   MSZoning       2604 non-null   object
#  5   LotFrontage    2141 non-null   float64
#  6   LotArea        2604 non-null   int64
#  7   Street         2604 non-null   object
#  8   Alley          170 non-null    object
#  9   LotShape       2604 non-null   object
#  10  LandContour    2604 non-null   object
#  11  Utilities      2604 non-null   object
#  12  LotConfig      2604 non-null   object
#  13  LandSlope      2604 non-null   object
#  14  Neighborhood   2604 non-null   object
#  15  Condition1     2604 non-null   object
#  16  Condition2     2604 non-null   object
#  17  BldgType       2604 non-null   object
#  18  HouseStyle     2604 non-null   object
#  19  OverallQual    2604 non-null   int64
#  20  OverallCond    2604 non-null   int64
#  21  YearBuilt      2604 non-null   int64
#  22  YearRemodAdd   2604 non-null   int64
#  23  RoofStyle      2604 non-null   object
#  24  RoofMatl       2604 non-null   object
#  25  Exterior1st    2604 non-null   object
#  26  Exterior2nd    2604 non-null   object
#  27  MasVnrType     2590 non-null   object
#  28  MasVnrArea     2590 non-null   float64
#  29  ExterQual      2604 non-null   object
#  30  ExterCond      2604 non-null   object
#  31  Foundation     2604 non-null   object
#  32  BsmtQual       2539 non-null   object
#  33  BsmtCond       2539 non-null   object
#  34  BsmtExposure   2537 non-null   object
#  35  BsmtFinType1   2539 non-null   object
#  36  BsmtFinSF1     2603 non-null   float64
#  37  BsmtFinType2   2538 non-null   object
#  38  BsmtFinSF2     2603 non-null   float64
#  39  BsmtUnfSF      2603 non-null   float64
#  40  TotalBsmtSF    2603 non-null   float64
#  41  Heating        2604 non-null   object
#  42  HeatingQC      2604 non-null   object
#  43  CentralAir     2604 non-null   object
#  44  Electrical     2603 non-null   object
#  45  1stFlrSF       2604 non-null   int64
#  46  2ndFlrSF       2604 non-null   int64
#  47  LowQualFinSF   2604 non-null   int64
#  48  BsmtFullBath   2602 non-null   float64
#  49  BsmtHalfBath   2602 non-null   float64
#  50  FullBath       2604 non-null   int64
#  51  HalfBath       2604 non-null   int64
#  52  BedroomAbvGr   2604 non-null   int64
#  53  KitchenAbvGr   2604 non-null   int64
#  54  KitchenQual    2604 non-null   object
#  55  TotRmsAbvGrd   2604 non-null   int64
#  56  Functional     2604 non-null   object
#  57  Fireplaces     2604 non-null   int64
#  58  FireplaceQu    1342 non-null   object
#  59  GarageType     2476 non-null   object
#  60  GarageYrBlt    2474 non-null   float64
#  61  GarageFinish   2474 non-null   object
#  62  GarageCars     2603 non-null   float64
#  63  GarageArea     2603 non-null   float64
#  64  GarageQual     2474 non-null   object
#  65  GarageCond     2474 non-null   object
#  66  PavedDrive     2604 non-null   object
#  67  WoodDeckSF     2604 non-null   int64
#  68  OpenPorchSF    2604 non-null   int64
#  69  EnclosedPorch  2604 non-null   int64
#  70  3SsnPorch      2604 non-null   int64
#  71  ScreenPorch    2604 non-null   int64
#  72  PoolArea       2604 non-null   int64
#  73  PoolQC         9 non-null      object
#  74  Fence          529 non-null    object
#  75  MiscFeature    98 non-null     object
#  76  MiscVal        2604 non-null   int64
#  77  MoSold         2604 non-null   int64
#  78  YrSold         2604 non-null   int64
#  79  SaleType       2604 non-null   object
#  80  SaleCondition  2604 non-null   object
#  81  Prop_Addr      2604 non-null   object
# dtypes: float64(11), int64(27), object(44)
# memory usage: 1.6+ MB
# Ames Summary:  None
# Total Unique Values:  PID              2559
# GrLivArea        1210
# SalePrice         861
# MSSubClass         16
# MSZoning            6
#                  ...
# MoSold             12
# YrSold              5
# SaleType           10
# SaleCondition       6
# Prop_Addr        2559
# Length: 82, dtype: int64

# %%
#YearBuilt, MoSold, YrSold, GarageYrBlt, YearRemodAdd are all currently integers...
#lets change the data type for later analysis

#YearBuilt
ames_merge.YearBuilt = ames_merge.YearBuilt.astype(str)


#MoSold
ames_merge.MoSold = ames_merge.MoSold.astype(str)


#YrSold
ames_merge.YrSold = ames_merge.YrSold.astype(str)


#GarageYrBlt
ames_merge.GarageYrBlt = ames_merge.GarageYrBlt.astype(str)


#YearRemodAdd
ames_merge.YearRemodAdd = ames_merge.YearRemodAdd.astype(str)

# %%
#lets check our dataframe
ames_merge.head()
# Out:
#          PID  GrLivArea  SalePrice  MSSubClass MSZoning  LotFrontage  LotArea  \
# 0  909176150        856     126000          30       RL          NaN     7890
# 1  905476230       1049     139500         120       RL         42.0     4235
# 2  905476230       1049     139500         120       RL         42.0     4235
# 3  911128020       1001     124900          30  C (all)         60.0     6060
# 4  535377150       1039     114000          70       RL         80.0     8146
#
#   Street Alley LotShape  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0   Pave   NaN      Reg  ...        0    NaN   NaN         NaN       0      3
# 1   Pave   NaN      Reg  ...        0    NaN   NaN         NaN       0      2
# 2   Pave   NaN      Reg  ...        0    NaN   NaN         NaN       0      2
# 3   Pave   NaN      Reg  ...        0    NaN   NaN         NaN       0     11
# 4   Pave   NaN      Reg  ...        0    NaN   NaN         NaN       0      5
#
#   YrSold SaleType SaleCondition         Prop_Addr
# 0   2010      WD         Normal   436 HAYWARD AVE
# 1   2009      WD         Normal      3416 WEST ST
# 2   2009      WD         Normal      3416 WEST ST
# 3   2007      WD         Normal      320 S 2ND ST
# 4   2009      WD         Normal  1524 DOUGLAS AVE
#
# [5 rows x 82 columns]

# %%
#based on the kaggle info about data types, some of the columns are coded.
#I will use a dictionary to convert the integers to more informative strings.

#MSSubClass 
ms_sub_dict = {
    20: "1-STORY 1946 & NEWER ALL STYLES",
    30: "1-STORY 1945 & OLDER",
    40: "1-STORY W/FINISHED ATTIC ALL AGES",
    45: "1-1/2 STORY - UNFINISHED ALL AGES",
    50: "1-1/2 STORY FINISHED ALL AGES",
    60: "2-STORY 1946 & NEWER",
    70: "2-STORY 1945 & OLDER",
    75: "2-1/2 STORY ALL AGES",
    80: "SPLIT OR MULTI-LEVEL",
    85: "SPLIT FOYER",
    90: "DUPLEX - ALL STYLES AND AGES",
    120: "1-STORY PUD (Planned Unit Development) - 1946 & NEWER",
    150: "1-1/2 STORY PUD - ALL AGES",
    160: "2-STORY PUD - 1946 & NEWER",
    180: "PUD - MULTILEVEL - INCL SPLIT LEV/FOYER",
    190: "2 FAMILY CONVERSION - ALL STYLES AND AGES",
}

#MSZoning
ms_zon_dict = {
    "A": "Agriculture",
    "C": "Commercial",
    "FV": "Floating Village Residential",
    "I": "Industrial",
    "RH": "Residential High Density",
    "RL": "Residential Low Density",
    "RP": "Residential Low Density Park", 
    "RM": "Residential Medium Density"
}

#Neighborhood
neighbor_dict = {
    "Blmngtn": "Bloomington Heights",
    "Blueste": "Bluestem",
    "BrDale": "Briardale",
    "BrkSide": "Brookside",
    "ClearCr": "Clear Creek",
    "CollgCr": "College Creek",
    "Crawfor": "Crawford",
    "Edwards": "Edwards",
    "Gilbert": "Gilbert",
    "IDOTRR": "Iowa DOT,Rail Road",
    "MeadowV": "Meadow Village",
    "Mitchel": "Mitchell",
    "Names": "North Ames",
    "NoRidge": "Northridge",
    "NPkVill": "Northpark Villa",
    "NridgHt": "Northridge Heights",
    "NWAmes": "Northwest Ames",
    "OldTown": "Old Town",
    "SWISU": "Southwest of ISU",
    "Sawyer": "Sawyer",
    "SawyerW": "Sawyer West",
    "Somerst": "Somerset",
    "StoneBr": "Stone Brook",
    "Timber": "Timberland",
    "Veenker": "Veenker"
}

#OveralQual
over_qual_dict = {
    10: "Very Excellent",
    9: "Excellent",
    8: "Very Good",
    7: "Good",
    6: "Above Average",
    5: "Average",
    4: "Below Average",
    3: "Fair",
    2: "Poor",
    1: "Very Poor",
}

#OverallCond
over_cond_dict = {
    10: "Very Excellent",
    9: "Excellent",
    8: "Very Good",
    7: "Good",
    6: "Above Average",
    5: "Average",
    4: "Below Average",
    3: "Fair",
    2: "Poor",
    1: "Very Poor",
}

ames_merge.replace(
    {
        "MSSubClass": ms_sub_dict,
        "MSZoning" : ms_zon_dict,
        "Neighborhood": neighbor_dict,
        "OverallQual": over_qual_dict,
        "OverallCond": over_cond_dict,
    },
    inplace=True,
)

# %%
#are there any duplicates?
dup_rows = ames_merge[ames_merge.duplicated()]
print("number of duplicate rows: ", dup_rows.shape)
# Out:
# number of duplicate rows:  (45, 82)

# %%
ames_merge[ames_merge.PID.duplicated()]
# Out:
#             PID  GrLivArea  SalePrice  \
# 2     905476230       1049     139500
# 39    902206020        492      61500
# 42    527455250        988     129250
# 45    914452190       1080     134000
# 48    532376250        925     133500
# 299   903429110       1944     179900
# 411   527214060       2698     535000
# 691   903225040       1274     135000
# 699   923226300       1092      85500
# 700   923226300       1092      85500
# 755   907252060       2184     254750
# 805   528439040       1538     260000
# 864   535455080        832     105500
# 907   907412020       1728     190000
# 1050  902106010       1558     150000
# 1085  535402070       1086     159950
# 1094  535450210       1224     132000
# 1100  903458060       1196     109900
# 1122  528106020       2402     555000
# 1123  528106020       2402     555000
# 1179  905402070       1383     122000
# 1206  528220040       1490     167800
# 1249  527145090       1280     180000
# 1355  923225360        988      91000
# 1458  905402110       1350     146000
# 1558  911225110        936      78000
# 1648  910226060       1638     139000
# 1668  533212020       1200     149500
# 1692  534276010        864     129900
# 1768  923225390        945     119500
# 1835  909276070       1717     194000
# 1920  909452102       1680     170000
# 1955  908127040        960      94750
# 1958  903456090        754      84500
# 2033  902128020        864     105000
# 2146  527454200       1456     146000
# 2210  906385020       1222     187000
# 2313  531452050        752     125000
# 2327  532353130        980     135000
# 2331  534455030       1496     141500
# 2336  534125210       1193     146500
# 2358  527451640        987     118000
# 2457  528235010       1432     188500
# 2478  535151040       1144     150000
# 2515  907135040       1097     145000
#
#                                              MSSubClass  \
# 2     1-STORY PUD (Planned Unit Development) - 1946 ...
# 39                                 1-STORY 1945 & OLDER
# 42                      1-STORY 1946 & NEWER ALL STYLES
# 45                      1-STORY 1946 & NEWER ALL STYLES
# 48                      1-STORY 1946 & NEWER ALL STYLES
# 299                                2-STORY 1945 & OLDER
# 411                                2-STORY 1946 & NEWER
# 691                       1-1/2 STORY FINISHED ALL AGES
# 699                          2-STORY PUD - 1946 & NEWER
# 700                          2-STORY PUD - 1946 & NEWER
# 755                                2-STORY 1946 & NEWER
# 805                     1-STORY 1946 & NEWER ALL STYLES
# 864                   1-1/2 STORY - UNFINISHED ALL AGES
# 907                                2-STORY 1946 & NEWER
# 1050                               2-STORY 1945 & OLDER
# 1085                               SPLIT OR MULTI-LEVEL
# 1094                      1-1/2 STORY FINISHED ALL AGES
# 1100                               1-STORY 1945 & OLDER
# 1122                    1-STORY 1946 & NEWER ALL STYLES
# 1123                    1-STORY 1946 & NEWER ALL STYLES
# 1179                    1-STORY 1946 & NEWER ALL STYLES
# 1206                               2-STORY 1946 & NEWER
# 1249  1-STORY PUD (Planned Unit Development) - 1946 ...
# 1355            PUD - MULTILEVEL - INCL SPLIT LEV/FOYER
# 1458                    1-STORY 1946 & NEWER ALL STYLES
# 1558                      1-1/2 STORY FINISHED ALL AGES
# 1648                      1-1/2 STORY FINISHED ALL AGES
# 1668                         2-STORY PUD - 1946 & NEWER
# 1692                    1-STORY 1946 & NEWER ALL STYLES
# 1768  1-STORY PUD (Planned Unit Development) - 1946 ...
# 1835                      1-1/2 STORY FINISHED ALL AGES
# 1920                    1-STORY 1946 & NEWER ALL STYLES
# 1955                    1-STORY 1946 & NEWER ALL STYLES
# 1958          2 FAMILY CONVERSION - ALL STYLES AND AGES
# 2033                    1-STORY 1946 & NEWER ALL STYLES
# 2146                         2-STORY PUD - 1946 & NEWER
# 2210                    1-STORY 1946 & NEWER ALL STYLES
# 2313  1-STORY PUD (Planned Unit Development) - 1946 ...
# 2327                    1-STORY 1946 & NEWER ALL STYLES
# 2331                    1-STORY 1946 & NEWER ALL STYLES
# 2336          2 FAMILY CONVERSION - ALL STYLES AND AGES
# 2358                         2-STORY PUD - 1946 & NEWER
# 2457                               2-STORY 1946 & NEWER
# 2478                    1-STORY 1946 & NEWER ALL STYLES
# 2515                    1-STORY 1946 & NEWER ALL STYLES
#
#                           MSZoning  LotFrontage  LotArea Street Alley  \
# 2          Residential Low Density         42.0     4235   Pave   NaN
# 39      Residential Medium Density         52.0     7830   Pave   NaN
# 42         Residential Low Density         65.0     7150   Pave   NaN
# 45         Residential Low Density         71.0     9187   Pave   NaN
# 48         Residential Low Density          NaN     8638   Pave   NaN
# 299     Residential Medium Density         68.0     9928   Pave  Grvl
# 411        Residential Low Density         82.0    16052   Pave   NaN
# 691     Residential Medium Density         50.0     6125   Pave   NaN
# 699     Residential Medium Density         21.0     1504   Pave   NaN
# 700     Residential Medium Density         21.0     1504   Pave   NaN
# 755        Residential Low Density          NaN    12334   Pave   NaN
# 805        Residential Low Density         74.0     8847   Pave   NaN
# 864        Residential Low Density         59.0     7227   Pave   NaN
# 907        Residential Low Density         65.0     9313   Pave   NaN
# 1050    Residential Medium Density         57.0     6406   Pave  Grvl
# 1085       Residential Low Density         85.0    13400   Pave   NaN
# 1094       Residential Low Density         60.0     8064   Pave   NaN
# 1100    Residential Medium Density         40.0     4800   Pave   NaN
# 1122       Residential Low Density        105.0    15431   Pave   NaN
# 1123       Residential Low Density        105.0    15431   Pave   NaN
# 1179       Residential Low Density          NaN    15635   Pave   NaN
# 1206       Residential Low Density         57.0     8918   Pave   NaN
# 1249       Residential Low Density         39.0     5070   Pave   NaN
# 1355    Residential Medium Density         21.0     1596   Pave   NaN
# 1458       Residential Low Density         75.0     9375   Pave   NaN
# 1558                       C (all)         60.0     8520   Grvl   NaN
# 1648    Residential Medium Density         75.0     9060   Pave   NaN
# 1668  Floating Village Residential         24.0     2544   Pave  Pave
# 1692       Residential Low Density         70.0     9100   Pave   NaN
# 1768    Residential Medium Density         31.0     2394   Pave   NaN
# 1835       Residential Low Density         80.0    12400   Pave   NaN
# 1920       Residential Low Density          NaN    17871   Pave   NaN
# 1955       Residential Low Density         73.0    10921   Pave   NaN
# 1958    Residential Medium Density         60.0     6780   Pave   NaN
# 2033    Residential Medium Density         60.0     7200   Pave  Grvl
# 2146       Residential Low Density         24.0     2280   Pave   NaN
# 2210       Residential Low Density         64.0     7360   Pave   NaN
# 2313       Residential Low Density         50.0     7175   Pave   NaN
# 2327       Residential Low Density         71.0     7064   Pave   NaN
# 2331       Residential Low Density         80.0     9600   Pave   NaN
# 2336       Residential Low Density         79.0    13110   Pave   NaN
# 2358    Residential Medium Density         21.0     1680   Pave   NaN
# 2457       Residential Low Density         71.0     7795   Pave   NaN
# 2478       Residential Low Density         73.0     8760   Pave   NaN
# 2515       Residential Low Density        112.0    10859   Pave   NaN
#
#      LotShape  ... PoolArea PoolQC  Fence MiscFeature MiscVal MoSold YrSold  \
# 2         Reg  ...        0    NaN    NaN         NaN       0      2   2009
# 39        Reg  ...        0    NaN    NaN         NaN       0      6   2006
# 42        Reg  ...        0    NaN    NaN         NaN       0     11   2007
# 45        Reg  ...        0    NaN    NaN         NaN       0      6   2007
# 48        IR1  ...        0    NaN    NaN         NaN       0     10   2006
# 299       Reg  ...        0    NaN    NaN        Shed     400      6   2009
# 411       IR1  ...        0    NaN    NaN         NaN       0      7   2006
# 691       Reg  ...        0    NaN    NaN         NaN       0      3   2007
# 699       Reg  ...        0    NaN    NaN         NaN       0      5   2007
# 700       Reg  ...        0    NaN    NaN         NaN       0      5   2007
# 755       IR1  ...        0    NaN    NaN         NaN       0      6   2009
# 805       Reg  ...        0    NaN    NaN         NaN       0     12   2007
# 864       Reg  ...        0    NaN    NaN         NaN       0      6   2008
# 907       IR1  ...        0    NaN    NaN         NaN       0      4   2009
# 1050      Reg  ...        0    NaN  MnPrv         NaN       0     10   2009
# 1085      Reg  ...        0    NaN   GdWo         NaN       0      6   2006
# 1094      Reg  ...        0    NaN   GdWo         NaN       0      5   2010
# 1100      Reg  ...        0    NaN    NaN         NaN       0      7   2007
# 1122      Reg  ...        0    NaN    NaN         NaN       0      4   2009
# 1123      Reg  ...        0    NaN    NaN         NaN       0      4   2009
# 1179      IR1  ...        0    NaN    NaN         NaN       0     10   2009
# 1206      IR1  ...        0    NaN    NaN         NaN       0      7   2009
# 1249      IR1  ...        0    NaN    NaN         NaN       0      8   2008
# 1355      Reg  ...        0    NaN   GdWo         NaN       0     11   2009
# 1458      Reg  ...        0    NaN    NaN         NaN       0      6   2006
# 1558      Reg  ...        0    NaN    NaN         NaN       0      4   2006
# 1648      Reg  ...        0    NaN    NaN         NaN       0      4   2006
# 1668      Reg  ...        0    NaN    NaN         NaN       0      2   2010
# 1692      Reg  ...        0    NaN    NaN         NaN       0      7   2006
# 1768      Reg  ...        0    NaN    NaN         NaN       0      5   2010
# 1835      Reg  ...        0    NaN    NaN         NaN       0      2   2006
# 1920      IR2  ...        0    NaN    NaN         NaN       0      6   2007
# 1955      Reg  ...        0    NaN    NaN         NaN       0      5   2007
# 1958      Reg  ...        0    NaN    NaN         NaN       0      6   2006
# 2033      Reg  ...        0    NaN    NaN         NaN       0      8   2006
# 2146      Reg  ...        0    NaN    NaN         NaN       0      7   2010
# 2210      Reg  ...        0    NaN    NaN         NaN       0      3   2010
# 2313      Reg  ...        0    NaN  MnPrv         NaN       0      2   2010
# 2327      Reg  ...        0    NaN    NaN         NaN       0      7   2009
# 2331      Reg  ...        0    NaN  MnPrv         NaN       0      2   2008
# 2336      IR1  ...        0    NaN  MnPrv         NaN       0      7   2006
# 2358      Reg  ...        0    NaN    NaN         NaN       0      5   2009
# 2457      IR1  ...        0    NaN    NaN         NaN       0      7   2009
# 2478      Reg  ...        0    NaN    NaN         NaN       0      6   2009
# 2515      Reg  ...        0    NaN    NaN         NaN       0      6   2009
#
#      SaleType SaleCondition                Prop_Addr
# 2         WD         Normal             3416 WEST ST
# 39        WD         Normal            118 E 11TH ST
# 42        WD         Normal             1115 28TH ST
# 45        WD         Normal             302 OPAL CIR
# 48        WD         Normal          4015 TORONTO ST
# 299       WD         Normal            716 HODGE AVE
# 411       New       Partial  4008 FRANCES E DAVIS CT
# 691       CWD        Normal         1217 CURTISS AVE
# 699       WD         Normal            609 MEADOW PL
# 700       WD         Normal            609 MEADOW PL
# 755       WD         Normal        4923 HEMINGWAY DR
# 805       WD         Normal        2607 YORKSHIRE ST
# 864       WD         Normal            201 E 13TH ST
# 907       WD         Normal           4915 WALLER ST
# 1050      WD         Normal              622 11TH ST
# 1085      WD         Normal         1909 MAXWELL AVE
# 1094      WD         Normal            1412 DUFF AVE
# 1100      WD         Normal          123 N MAPLE AVE
# 1122      WD         Normal        3324 STOCKBURY ST
# 1123      WD         Normal        3324 STOCKBURY ST
# 1179      WD         Normal            3618 MARY CIR
# 1206      WD         Normal           2719 LAUREL ST
# 1249      WD         Normal       4028 FLETCHER BLVD
# 1355      WD         Normal            548 MEADOW CT
# 1458      WD         Normal         3603 WOODLAND ST
# 1558      WD         Normal           119 CHERRY AVE
# 1648      WD         Normal          208 S MAPLE AVE
# 1668      WD         Normal           2629 STANGE RD
# 1692      WD         Normal        2317 FERNDALE AVE
# 1768      WD         Normal            540 MEADOW CT
# 1835      WD         Normal          2022 GREELEY ST
# 1920      WD         Normal             2220 ASH AVE
# 1955      WD         Normal            205 DOTSON DR
# 1958      WD         Normal       102 N RIVERSIDE DR
# 2033      COD        Normal              314 12TH ST
# 2146      WD         Normal          1139 JOHNSON ST
# 2210      WD         Normal           5513 DURANT ST
# 2313      WD         Normal         1320 INDIANA AVE
# 2327      WD         Normal       1310 WOODSTOCK AVE
# 2331      WD         Normal             1410 16TH ST
# 2336      WD         Normal             1819 24TH ST
# 2358      WD         Normal     1461 BRECKINRIDGE CT
# 2457      WD         Normal        4009 BRICKMAN AVE
# 2478      WD         Normal          2203 JENSEN AVE
# 2515      WD         Normal            5421 FROST DR
#
# [45 rows x 82 columns]

# %%
#drop duplicates
ames_merge.drop_duplicates(inplace=True)

# %%
#check to make sure its dropped
ames_merge[ames_merge.PID.duplicated()]
# Out:
# Empty DataFrame
# Columns: [PID, GrLivArea, SalePrice, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, Prop_Addr]
# Index: []
#
# [0 rows x 82 columns]

# %% [markdown]
# # Missing Values?

# %%
#missing data
total_missing = ames_merge.isnull().sum().sort_values(ascending=False)
percent = (ames_merge.isnull().sum()/ames_merge.isnull().count()).sort_values(ascending=False) * 100
missing_data = pd.concat([total_missing, percent], axis=1, keys=["Total", "Percent"])
missing_data.head(20)
# Out:
#               Total    Percent
# PoolQC         2550  99.648300
# MiscFeature    2462  96.209457
# Alley          2393  93.513091
# Fence          2037  79.601407
# FireplaceQu    1229  48.026573
# LotFrontage     459  17.936694
# GarageQual      128   5.001954
# GarageFinish    128   5.001954
# GarageCond      128   5.001954
# GarageType      126   4.923798
# BsmtExposure     66   2.579132
# BsmtFinType2     65   2.540055
# BsmtFinType1     64   2.500977
# BsmtQual         64   2.500977
# BsmtCond         64   2.500977
# MasVnrType       14   0.547089
# MasVnrArea       14   0.547089
# BsmtFullBath      2   0.078156
# BsmtHalfBath      2   0.078156
# BsmtFinSF1        1   0.039078

# %% [markdown]
# missing values likely related to not having certain feature

# %%
#first lets replace the categorical missing values
ames_merge.fillna(value={
    "Alley": "NoAlley",
    "BsmtQual": "NoBsmt",
    "BsmtCond": "NoBsmt",
    "BsmtExposure": "NoBsmt",
    "BsmtFinType1": "NoBsmt",
    "BsmtFinType2": "NoBsmt",
    "FireplaceQu": "NoFirepl",
    "GarageType": "NoGrge",
    "GarageFinish": "NoGrge",
    "GarageQual": "NoGrge",
    "GarageCond": "NoGrge",
    "PoolQC": "NoPool",
    "Fence": "NoFence",
    "MiscFeature": "NoMisc", 
    "MasVnrType": "None"
},
inplace=True)

# %%
#what is still missing?
total_missing = ames_merge.isnull().sum().sort_values(ascending=False)
percent = (ames_merge.isnull().sum()/ames_merge.isnull().count()).sort_values(ascending=False) * 100
missing_data = pd.concat([total_missing, percent], axis=1, keys=["Total", "Percent"])
missing_data.head(15)
# Out:
#               Total    Percent
# LotFrontage     459  17.936694
# MasVnrArea       14   0.547089
# BsmtFullBath      2   0.078156
# BsmtHalfBath      2   0.078156
# Electrical        1   0.039078
# GarageCars        1   0.039078
# TotalBsmtSF       1   0.039078
# BsmtUnfSF         1   0.039078
# BsmtFinSF2        1   0.039078
# BsmtFinSF1        1   0.039078
# GarageArea        1   0.039078
# PID               0   0.000000
# TotRmsAbvGrd      0   0.000000
# Fireplaces        0   0.000000
# Functional        0   0.000000

# %% [markdown]
# According to Kaggle, LotFrontage describes the linear feet of street connected to property.
# This could be zero because the listing is a condo or an apartment, but it should not impact my analysis.

# %%
#now lets replace the numerical missing values
ames_merge.fillna(value=0, method=None, axis=1, inplace=True, limit=None,
                downcast=None)
print(f"Housing Null Values: {ames_merge.isnull().sum(axis=0)}")
# Out:
# Housing Null Values: PID              0
# GrLivArea        0
# SalePrice        0
# MSSubClass       0
# MSZoning         0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# Prop_Addr        0
# Length: 82, dtype: int64

# %% [markdown]
# # could there be potential outliers?
# According to Jean De Cock, there are 5 outliers that are over 4000 SF.
# source: http://jse.amstat.org/v19n3/decock.pdf
# Lets take a look:

# %%
ames_merge["GrLivArea"].sort_values(ascending=False).head()
# there only appears to be 2 listings over 4000SF. Were the others already removed?
# Out:
# 313     4676
# 1013    4316
# 2329    3820
# 392     3672
# 1339    3627
# Name: GrLivArea, dtype: int64

# %%
# Remove large properties
ames_merge = ames_merge[ames_merge.GrLivArea < 4000]

# %%
#convert the cleaned dataframe back to csv
ames_merge.to_csv("ames_clean.csv")
